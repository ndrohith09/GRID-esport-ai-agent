# %%
import requests, json
import pandas as pd
from datetime import datetime

url = "https://api-op.grid.gg/central-data/graphql"
headers = {"x-api-key": ""}

# Valorant ID - 6
# LOL ID - 3
# gte: "2025-01-01T15:00:07+02:00"
# lte: "2026-01-20T15:00:07+02:00"

# %% [markdown]
# # Get Tournaments
# ### (issue not match with series tournament IDs)

# %%
tournaments_query = """query GetTournaments($first: Int, $after: String) {
  tournaments (
  first: $first, 
    after: $after,
    filter : {
    title: { id: { in: ["6"] } },
       startDate: {
        gte: "2024-01-01" 
		    lte: "2026-01-20"
      }
  }) {
    pageInfo {
      hasPreviousPage
      hasNextPage
      startCursor
      endCursor
    }
    totalCount
    edges {
      cursor
      node {
        ...tournamentFields
      }
    }
  }
}
fragment tournamentFields on Tournament {
  id
  name
  nameShortened
  startDate
  endDate
  venueType
  titles{
    id
    name
  }
  teams{
    name
    id
  }
  children{
    id
    name
  }
}"""

all_tournaments = []
has_next = True
cursor = None  # Start with no cursor
limit = 10     # How many results per page

while has_next:
    # Pass variables into the JSON payload
    variables = {
        "first": limit,
        "after": cursor
    }
    payload = {
    "query": tournaments_query,
    "variables": variables
}
    response = requests.post(
        url, 
        json={'query': tournaments_query, 'variables': variables}, 
        headers=headers
    )
    
    if response.status_code == 200:
        data = response.json()
        print(data)
        result = data['data']['tournaments']
        
        # 1. Add current page nodes to our list
        all_tournaments.extend([edge['node'] for edge in result['edges']])
        
        # 2. Update pagination info
        has_next = result['pageInfo']['hasNextPage']
        cursor = result['pageInfo']['endCursor']
        
        print(f"Fetched {len(result['edges'])} items. Next page available: {has_next}")
    else:
        print(f"Error: {response.text}")
        break

print(f"Total tournaments collected: {len(all_tournaments)}")
# Out:
# {'data': {'tournaments': {'pageInfo': {'hasPreviousPage': False, 'hasNextPage': False, 'startCursor': 'PjMLC1oLC0BCQERARgsLWgsL', 'endCursor': 'PjMLC1oLC09FQUFBRwsLWgsL'}, 'totalCount': 7, 'edges': [{'cursor': 'PjMLC1oLC0BCQERARgsLWgsL', 'node': {'id': '757371', 'name': 'VCT Americas - Kickoff 2024', 'nameShortened': 'Kickoff 2024', 'startDate': '2024-02-15', 'endDate': '2024-03-04', 'venueType': 'LAN', 'titles': [{'id': '6', 'name': 'Valorant'}], 'teams': [{'name': 'NRG', 'id': '97'}, {'name': 'FURIA', 'id': '99'}, {'name': 'Cloud9', 'id': '79'}, {'name': 'MIBR (1)', 'id': '81'}, {'name': 'LOUD (1)', 'id': '3412'}, {'name': 'Sentinels', 'id': '1079'}, {'name': 'Leviatán Esports', 'id': '1611'}, {'name': '100 Thieves', 'id': '337'}, {'name': 'KRÜ Esports', 'id': '48457'}, {'name': 'G2 Esports', 'id': '96'}, {'name': 'Evil Geniuses', 'id': '281'}], 'children': [{'id': '757372', 'name': 'VCT Americas - Kickoff 2024 (Groups)'}, {'id': '757581', 'name': 'VCT Americas - Kickoff 2024 (Playoffs)'}, {'id': '757584', 'name': 'VCT Americas - Kickoff 2024 (Play-Ins)'}]}}, {'cursor': 'PjMLC1oLC0BCQENPRgsLWgsL', 'node': {'id': '757481', 'name': 'VCT Americas - Stage 1 2024', 'nameShortened': 'Stage 1 2024', 'startDate': '2024-04-06', 'endDate': '2024-05-12', 'venueType': 'LAN', 'titles': [{'id': '6', 'name': 'Valorant'}], 'teams': [{'name': 'Sentinels', 'id': '1079'}, {'name': 'Cloud9', 'id': '79'}, {'name': 'G2 Esports', 'id': '96'}, {'name': 'KRÜ Esports', 'id': '48457'}, {'name': 'NRG', 'id': '97'}, {'name': 'Leviatán Esports', 'id': '1611'}, {'name': 'LOUD (1)', 'id': '3412'}, {'name': '100 Thieves', 'id': '337'}, {'name': 'MIBR (1)', 'id': '81'}, {'name': 'FURIA', 'id': '99'}, {'name': 'Evil Geniuses', 'id': '281'}], 'children': [{'id': '757482', 'name': 'VCT Americas - Stage 1 2024 (Regular Season)'}, {'id': '757619', 'name': 'VCT Americas - Stage 1 2024 (Playoffs)'}]}}, {'cursor': 'PjMLC1oLC0BCQEFGQwsLWgsL', 'node': {'id': '757614', 'name': 'VALORANT Masters - Masters Madrid', 'nameShortened': 'Masters Madrid', 'startDate': '2024-03-14', 'endDate': '2024-03-24', 'venueType': 'LAN', 'titles': [{'id': '6', 'name': 'Valorant'}], 'teams': [{'name': 'LOUD (1)', 'id': '3412'}, {'name': 'Sentinels', 'id': '1079'}, {'name': 'Team Heretics', 'id': '173'}, {'name': 'Karmine Corp (1)', 'id': '3554'}, {'name': 'Gen.G', 'id': '404'}, {'name': 'Paper Rex', 'id': '917'}, {'name': 'FunPlus Phoenix', 'id': '361'}, {'name': 'EDward Gaming', 'id': '359'}], 'children': [{'id': '757615', 'name': 'VCT Masters - Masters Madrid (Swiss)'}, {'id': '757616', 'name': 'VALORANT Masters - Masters Madrid (Playoffs)'}]}}, {'cursor': 'PjMLC1oLC0BAQ0BPRQsLWgsL', 'node': {'id': '774782', 'name': 'VCT Americas - Stage 2 2024', 'nameShortened': 'Stage 2 2024', 'startDate': '2024-06-16', 'endDate': '2024-07-22', 'venueType': 'LAN', 'titles': [{'id': '6', 'name': 'Valorant'}], 'teams': [{'name': 'Leviatán Esports', 'id': '1611'}, {'name': '100 Thieves', 'id': '337'}, {'name': 'LOUD (1)', 'id': '3412'}, {'name': 'Evil Geniuses', 'id': '281'}, {'name': 'FURIA', 'id': '99'}, {'name': 'MIBR (1)', 'id': '81'}, {'name': 'KRÜ Esports', 'id': '48457'}, {'name': 'Cloud9', 'id': '79'}, {'name': 'G2 Esports', 'id': '96'}, {'name': 'Sentinels', 'id': '1079'}, {'name': 'NRG', 'id': '97'}], 'children': [{'id': '774783', 'name': 'VCT Americas - Stage 2 2024 (Regular Season)'}, {'id': '774786', 'name': 'VCT Americas - Stage 2 2024 (Playoffs)'}]}}, {'cursor': 'PjMLC1oLC0BAQkJGQQsLWgsL', 'node': {'id': '775516', 'name': 'VCT Americas - Kickoff 2025', 'nameShortened': 'Kickoff 2025', 'startDate': '2025-01-16', 'endDate': '2025-02-08', 'venueType': 'LAN', 'titles': [{'id': '6', 'name': 'Valorant'}], 'teams': [{'name': 'Evil Geniuses', 'id': '281'}, {'name': 'LOUD (1)', 'id': '3412'}, {'name': 'MIBR (1)', 'id': '81'}, {'name': '100 Thieves', 'id': '337'}, {'name': '2GAME eSports', 'id': '53367'}, {'name': 'FURIA', 'id': '99'}, {'name': 'NRG', 'id': '97'}, {'name': 'Cloud9', 'id': '79'}, {'na ...
# Fetched 7 items. Next page available: False
# Total tournaments collected: 7

# %%
def tournaments_to_dataframe(all_tournaments):
    rows = []

    for t in all_tournaments:
        title = t["titles"][0] if t.get("titles") else {}

        teams = t.get("teams", [])
        team_ids = [team["id"] for team in teams if "id" in team]

        rows.append({
            "tournament_id": t.get("id"),
            "tournament_name": t.get("name"),
            "start_date": t.get("startDate"),
            "end_date": t.get("endDate"),
            "venue_type": t.get("venueType"),
            "title_id": title.get("id"),
            "title_name": title.get("name"),
            "children": json.dumps(t.get('children', [])),
            "num_teams": len(teams),
            "teams_id": team_ids,
        })

    df = pd.DataFrame(rows)

    # Convert the list column to a string before saving to SQL
    df['teams_id'] = df['teams_id'].apply(lambda x: ','.join(map(str, x)))

  # Convert to datetime for timeline logic
    df["start_date"] = pd.to_datetime(df["start_date"])
    df["start_date"] = df["start_date"].dt.strftime('%Y-%m-%d')
    df["end_date"] = pd.to_datetime(df["end_date"])
    df["end_date"] = df["end_date"].dt.strftime('%Y-%m-%d')

    # Sort chronologically (important for timeline models)
    df = df.sort_values("start_date").reset_index(drop=True)

    return df
df_tournaments = tournaments_to_dataframe(all_tournaments)
df_tournaments
# Out:
#   tournament_id                    tournament_name  start_date    end_date  \
# 0        757371        VCT Americas - Kickoff 2024  2024-02-15  2024-03-04
# 1        757614  VALORANT Masters - Masters Madrid  2024-03-14  2024-03-24
# 2        757481        VCT Americas - Stage 1 2024  2024-04-06  2024-05-12
# 3        774782        VCT Americas - Stage 2 2024  2024-06-16  2024-07-22
# 4        775516        VCT Americas - Kickoff 2025  2025-01-16  2025-02-08
# 5        800675        VCT Americas - Stage 1 2025  2025-03-21  2025-05-04
# 6        826660        VCT Americas - Stage 2 2025  2025-07-18  2025-09-01
#
#   venue_type title_id title_name  \
# 0        LAN        6   Valorant
# 1        LAN        6   Valorant
# 2        LAN        6   Valorant
# 3        LAN        6   Valorant
# 4        LAN        6   Valorant
# 5        LAN        6   Valorant
# 6        LAN        6   Valorant
#
#                                             children  num_teams  \
# 0  [{"id": "757372", "name": "VCT Americas - Kick...         11
# 1  [{"id": "757615", "name": "VCT Masters - Maste...          8
# 2  [{"id": "757482", "name": "VCT Americas - Stag...         11
# 3  [{"id": "774783", "name": "VCT Americas - Stag...         11
# 4  [{"id": "775517", "name": "VCT Americas - Kick...         12
# 5  [{"id": "800676", "name": "VCT Americas - Stag...         12
# 6  [{"id": "826661", "name": "VCT Americas - Stag...         12
#
#                                             teams_id
# 0        97,99,79,81,3412,1079,1611,337,48457,96,281
# 1                 3412,1079,173,3554,404,917,361,359
# 2        1079,79,96,48457,97,1611,3412,337,81,99,281
# 3        1611,337,3412,281,99,81,48457,79,96,1079,97
# 4  281,3412,81,337,53367,99,97,79,48457,1079,1611,96
# 5  281,3412,81,337,53367,99,97,79,48457,1079,1611,96
# 6  281,3412,81,337,53367,99,97,79,48457,1079,1611,96

# %%
df_tournaments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tournament_id    7 non-null      object
#  1   tournament_name  7 non-null      object
#  2   start_date       7 non-null      object
#  3   end_date         7 non-null      object
#  4   venue_type       7 non-null      object
#  5   title_id         7 non-null      object
#  6   title_name       7 non-null      object
#  7   children         7 non-null      object
#  8   num_teams        7 non-null      int64
#  9   teams_id         7 non-null      object
# dtypes: int64(1), object(9)
# memory usage: 692.0+ bytes

# %%
import pandas as pd

from sqlalchemy import create_engine
# 'sqlite:///filename.db' for local file
engine = create_engine('sqlite:///valorant_esports.db')

df_tournaments.to_sql('tournaments', con=engine, if_exists='replace')
# Out:
# 7

# %% [markdown]
# # Series Data

# %%
series_query = """
query GetAllSeries($first: Int, $after: String) {
  allSeries(
  first: $first, 
    after: $after,
    filter:{
      titleId: 6,
      startTimeScheduled:{
        gte: "2024-01-01T15:00:07+02:00"
        lte: "2026-01-20T15:00:07+02:00"
      }
    }
    orderBy: StartTimeScheduled    
  ) {
    totalCount,
    pageInfo{
      hasPreviousPage
      hasNextPage
      startCursor
      endCursor
    }
    edges{
      cursor
      node{
        ...seriesFields
      }
    }
  }
}
fragment seriesFields on Series {
  id
  title {
    name
  }
  type
  tournament {
    id
    name
    nameShortened
  }
  players{
    id
    nickname    
  }
  startTimeScheduled
  format {
    name
    nameShortened
  }
  teams {
    baseInfo {
      name
      id
    }    
    scoreAdvantage
  }
}""" 

all_series = []
has_next = True
cursor = None  # Start with no cursor
limit = 50    # How many results per page

while has_next:
    # Pass variables into the JSON payload
    variables = {
        "first": limit,
        "after": cursor
    }
    payload = {
    "query": series_query,
    "variables": variables
}
    response = requests.post(
        url, 
        json={'query': series_query, 'variables': variables}, 
        headers=headers
    )
    
    if response.status_code == 200:
        data = response.json()
        print(data)
        result = data['data']['allSeries']
        
        # 1. Add current page nodes to our list
        all_series.extend([edge['node'] for edge in result['edges']])
        
        # 2. Update pagination info
        has_next = result['pageInfo']['hasNextPage']
        cursor = result['pageInfo']['endCursor']
        
        print(f"Fetched {len(result['edges'])} items. Next page available: {has_next}")
    else:
        print(f"Error: {response.text}")
        break

print(f"Total series collected: {len(all_series)}")
# Out:
# {'data': {'allSeries': {'totalCount': 212, 'pageInfo': {'hasPreviousPage': False, 'hasNextPage': True, 'startCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUVORE5HCwtaCwtFR0VDWkdFWkZBI0VFTUdHTUdHLQ==', 'endCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUJETk9DCwtaCwtFR0VDWkdDWkVFI0VGTUdHTUdHLQ=='}, 'edges': [{'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUVORE5HCwtaCwtFR0VDWkdFWkZBI0VFTUdHTUdHLQ==', 'node': {'id': '2629390', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '757073', 'name': 'VCT Americas - Kickoff 2024 (Groups: Group A)', 'nameShortened': 'Group A'}, 'players': [], 'startTimeScheduled': '2024-02-16T22:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'FURIA', 'id': '99'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'NRG', 'id': '97'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUVORE5GCwtaCwtFR0VDWkdFWkZAI0dGTUdHTUdHLQ==', 'node': {'id': '2629391', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '757073', 'name': 'VCT Americas - Kickoff 2024 (Groups: Group A)', 'nameShortened': 'Group A'}, 'players': [], 'startTimeScheduled': '2024-02-17T01:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'MIBR (1)', 'id': '81'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Cloud9', 'id': '79'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUVORE5FCwtaCwtFR0VDWkdFWkZAI0VFTUdHTUdHLQ==', 'node': {'id': '2629392', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '757628', 'name': 'VCT Americas - Kickoff 2024 (Groups: Group B)', 'nameShortened': 'Group B'}, 'players': [], 'startTimeScheduled': '2024-02-17T22:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'Sentinels', 'id': '1079'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'LOUD (1)', 'id': '3412'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUVORE5ECwtaCwtFR0VDWkdFWkZPI0dGTUdHTUdHLQ==', 'node': {'id': '2629393', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '757628', 'name': 'VCT Americas - Kickoff 2024 (Groups: Group B)', 'nameShortened': 'Group B'}, 'players': [], 'startTimeScheduled': '2024-02-18T01:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': '100 Thieves', 'id': '337'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Leviatán Esports', 'id': '1611'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUVORE5DCwtaCwtFR0VDWkdFWkZPI0VFTUdHTUdHLQ==', 'node': {'id': '2629394', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '757629', 'name': 'VCT Americas - Kickoff 2024 (Groups: Group C)', 'nameShortened': 'Group C'}, 'players': [], 'startTimeScheduled': '2024-02-18T22:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'G2 Esports', 'id': '96'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'KRÜ Esports', 'id': '48457'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUVORE5CCwtaCwtFR0VDWkdFWkZOI0VFTUdHTUdHLQ==', 'node': {'id': '2629395', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '757073', 'name': 'VCT Americas - Kickoff 2024 (Groups: Group A)', 'nameShortened': 'Group A'}, 'players': [], 'startTimeScheduled': '2024-02-19T22:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'MIBR (1)', 'id': '81'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'FURIA', 'id': '99'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUVORE5BCwtaCwtFR0VDWkdFWkVHI0dGTUdHTUdHLQ==', 'node': {'id': '2629396', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '757628', 'name': 'VCT Americas - Kickoff 2024 (Groups: Group B)', 'nameShortened': 'Group B'}, 'players': [], 'startTimeScheduled': '2024-02-20T01:00:00Z', 'format': {'name': 'b ...
# Fetched 50 items. Next page available: True
# {'data': {'allSeries': {'totalCount': 212, 'pageInfo': {'hasPreviousPage': True, 'hasNextPage': True, 'startCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUJETk9CCwtaCwtFR0VDWkdDWkVEI0dHTUdHTUdHLQ==', 'endCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQU9GT0NGCwtaCwtFR0VDWkdAWkZPI0dHTUdHTUdHLQ=='}, 'edges': [{'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUJETk9CCwtaCwtFR0VDWkdDWkVEI0dHTUdHTUdHLQ==', 'node': {'id': '2653985', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '758114', 'name': 'VCT Americas - Stage 1 2024 (Regular Season: Alpha Group)', 'nameShortened': 'Alpha Group'}, 'players': [], 'startTimeScheduled': '2024-04-23T00:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'Cloud9', 'id': '79'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': '100 Thieves', 'id': '337'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUJETk9BCwtaCwtFR0VDWkdDWkVEI0VGTUdHTUdHLQ==', 'node': {'id': '2653986', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '758114', 'name': 'VCT Americas - Stage 1 2024 (Regular Season: Alpha Group)', 'nameShortened': 'Alpha Group'}, 'players': [], 'startTimeScheduled': '2024-04-23T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'Sentinels', 'id': '1079'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Evil Geniuses', 'id': '281'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUJETk9ACwtaCwtFR0VDWkdDWkVDI0dHTUdHTUdHLQ==', 'node': {'id': '2653987', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '758114', 'name': 'VCT Americas - Stage 1 2024 (Regular Season: Alpha Group)', 'nameShortened': 'Alpha Group'}, 'players': [], 'startTimeScheduled': '2024-04-24T00:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'NRG', 'id': '97'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'MIBR (1)', 'id': '81'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUJETk9PCwtaCwtFR0VDWkdDWkVDI0VGTUdHTUdHLQ==', 'node': {'id': '2653988', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '758114', 'name': 'VCT Americas - Stage 1 2024 (Regular Season: Alpha Group)', 'nameShortened': 'Alpha Group'}, 'players': [], 'startTimeScheduled': '2024-04-24T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'G2 Esports', 'id': '96'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Leviatán Esports', 'id': '1611'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUJETk9OCwtaCwtFR0VDWkdDWkVCI0dHTUdHTUdHLQ==', 'node': {'id': '2653989', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '758114', 'name': 'VCT Americas - Stage 1 2024 (Regular Season: Alpha Group)', 'nameShortened': 'Alpha Group'}, 'players': [], 'startTimeScheduled': '2024-04-25T00:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'KRÜ Esports', 'id': '48457'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'LOUD (1)', 'id': '3412'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUJETk5HCwtaCwtFR0VDWkdDWkVAI0VGTUdHTUdHLQ==', 'node': {'id': '2653990', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '758114', 'name': 'VCT Americas - Stage 1 2024 (Regular Season: Alpha Group)', 'nameShortened': 'Alpha Group'}, 'players': [], 'startTimeScheduled': '2024-04-27T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'G2 Esports', 'id': '96'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'MIBR (1)', 'id': '81'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQUJETk5GCwtaCwtFR0VDWkdDWkVPI0dHTUdHTUdHLQ==', 'node': {'id': '2653991', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '758114', 'name': 'VCT Americas - Stage 1 2024 (Regular Season: Alpha ...
# Fetched 50 items. Next page available: True
# {'data': {'allSeries': {'totalCount': 212, 'pageInfo': {'hasPreviousPage': True, 'hasNextPage': True, 'startCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQU9GT0NFCwtaCwtFR0VDWkdAWkZPI0VGTUdHTUdHLQ==', 'endCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQEBCTkBDCwtaCwtFR0VCWkdDWkZEI0dHTUdHTUdHLQ=='}, 'edges': [{'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQU9GT0NFCwtaCwtFR0VDWkdAWkZPI0VGTUdHTUdHLQ==', 'node': {'id': '2681842', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '774787', 'name': 'VCT Americas - Stage 2 2024 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [], 'startTimeScheduled': '2024-07-18T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'KRÜ Esports', 'id': '48457'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Leviatán Esports', 'id': '1611'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQU9GT0NECwtaCwtFR0VDWkdAWkZOI0dHTUdHTUdHLQ==', 'node': {'id': '2681843', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '774787', 'name': 'VCT Americas - Stage 2 2024 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [], 'startTimeScheduled': '2024-07-19T00:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': '100 Thieves', 'id': '337'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'G2 Esports', 'id': '96'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQU9GT0NDCwtaCwtFR0VDWkdAWkZOI0VGTUdHTUdHLQ==', 'node': {'id': '2681844', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '774787', 'name': 'VCT Americas - Stage 2 2024 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [], 'startTimeScheduled': '2024-07-19T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'G2 Esports', 'id': '96'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Leviatán Esports', 'id': '1611'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQU9GT0NCCwtaCwtFR0VDWkdAWkVHI0dHTUdHTUdHLQ==', 'node': {'id': '2681845', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '774787', 'name': 'VCT Americas - Stage 2 2024 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [], 'startTimeScheduled': '2024-07-20T00:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': '100 Thieves', 'id': '337'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'KRÜ Esports', 'id': '48457'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQU9GT0NBCwtaCwtFR0VDWkdAWkVHI0VGTUdHTUdHLQ==', 'node': {'id': '2681846', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '774787', 'name': 'VCT Americas - Stage 2 2024 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [], 'startTimeScheduled': '2024-07-20T21:00:00Z', 'format': {'name': 'best-of-5', 'nameShortened': 'Bo5'}, 'teams': [{'baseInfo': {'name': 'KRÜ Esports', 'id': '48457'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Leviatán Esports', 'id': '1611'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQU9GT0NACwtaCwtFR0VDWkdAWkVGI0VGTUdHTUdHLQ==', 'node': {'id': '2681847', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '774787', 'name': 'VCT Americas - Stage 2 2024 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [], 'startTimeScheduled': '2024-07-21T21:00:00Z', 'format': {'name': 'best-of-5', 'nameShortened': 'Bo5'}, 'teams': [{'baseInfo': {'name': 'Leviatán Esports', 'id': '1611'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'G2 Esports', 'id': '96'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENPQENECwtaCwtFR0VCWkdGWkZBI0VFTUdHTUdHLQ==', 'node': {'id': '2748743', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '775518', 'name': 'VCT Americas - Kickoff 2025 (Knockouts: Knockouts)', 'nameShortened': 'Knockou ...
# Fetched 50 items. Next page available: True
# {'data': {'allSeries': {'totalCount': 212, 'pageInfo': {'hasPreviousPage': True, 'hasNextPage': True, 'startCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQEBCTkBCCwtaCwtFR0VCWkdDWkZEI0VGTUdHTUdHLQ==', 'endCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFT0ZOQEdCCwtaCwtFR0VCWkdPWkZPI0dHTUdHTUdHLQ=='}, 'edges': [{'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQEBCTkBCCwtaCwtFR0VCWkdDWkZEI0VGTUdHTUdHLQ==', 'node': {'id': '2775975', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '800678', 'name': 'VCT Americas - Stage 1 2025 (Regular Season: Group A)', 'nameShortened': 'Group A'}, 'players': [], 'startTimeScheduled': '2025-04-13T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'KRÜ Esports', 'id': '48457'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Evil Geniuses', 'id': '281'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQEBCTkBBCwtaCwtFR0VCWkdDWkZDI0dHTUdHTUdHLQ==', 'node': {'id': '2775976', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '800677', 'name': 'VCT Americas - Stage 1 2025 (Regular Season: Group B)', 'nameShortened': 'Group B'}, 'players': [], 'startTimeScheduled': '2025-04-14T00:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'NRG', 'id': '97'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'MIBR (1)', 'id': '81'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQEBCTkBACwtaCwtFR0VCWkdDWkZPI0VGTUdHTUdHLQ==', 'node': {'id': '2775977', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '800677', 'name': 'VCT Americas - Stage 1 2025 (Regular Season: Group B)', 'nameShortened': 'Group B'}, 'players': [], 'startTimeScheduled': '2025-04-18T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'G2 Esports', 'id': '96'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Cloud9', 'id': '79'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQEBCTkBPCwtaCwtFR0VCWkdDWkZOI0dHTUdHTUdHLQ==', 'node': {'id': '2775978', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '800677', 'name': 'VCT Americas - Stage 1 2025 (Regular Season: Group B)', 'nameShortened': 'Group B'}, 'players': [], 'startTimeScheduled': '2025-04-19T00:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'MIBR (1)', 'id': '81'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'FURIA', 'id': '99'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQEBCTkBOCwtaCwtFR0VCWkdDWkZOI0VGTUdHTUdHLQ==', 'node': {'id': '2775979', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '800678', 'name': 'VCT Americas - Stage 1 2025 (Regular Season: Group A)', 'nameShortened': 'Group A'}, 'players': [], 'startTimeScheduled': '2025-04-19T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'Sentinels', 'id': '1079'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': '2GAME eSports', 'id': '53367'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQEBCTk9HCwtaCwtFR0VCWkdDWkVHI0dHTUdHTUdHLQ==', 'node': {'id': '2775980', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '800678', 'name': 'VCT Americas - Stage 1 2025 (Regular Season: Group A)', 'nameShortened': 'Group A'}, 'players': [], 'startTimeScheduled': '2025-04-20T00:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': '100 Thieves', 'id': '337'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'KRÜ Esports', 'id': '48457'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQEBCTk9GCwtaCwtFR0VCWkdDWkVHI0VGTUdHTUdHLQ==', 'node': {'id': '2775981', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '800678', 'name': 'VCT Americas - Stage 1 2025 (Regular Season: Group A)', 'nameShortened': 'Group A'}, 'players': [], ' ...
# Fetched 50 items. Next page available: True
# {'data': {'allSeries': {'totalCount': 212, 'pageInfo': {'hasPreviousPage': True, 'hasNextPage': False, 'startCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFT0NER0FHCwtaCwtFR0VCWkdPWkVGI0VGTUdHTUdHLQ==', 'endCursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFT0NER0BGCwtaCwtFR0VCWkdPWkRGI0VGTUdHTUdHLQ=='}, 'edges': [{'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFT0NER0FHCwtaCwtFR0VCWkdPWkVGI0VGTUdHTUdHLQ==', 'node': {'id': '2843060', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '826992', 'name': 'VCT Americas - Stage 2 2025 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [{'id': '1193', 'nickname': 'Xeppaa'}, {'id': '10636', 'nickname': 'OXY'}, {'id': '2348', 'nickname': 'neT'}, {'id': '2890', 'nickname': 'Rossy'}, {'id': '10612', 'nickname': 'v1c'}, {'id': '1195', 'nickname': 'mitch'}, {'id': '272', 'nickname': 'tuyz'}, {'id': '277', 'nickname': 'pANcada'}, {'id': '11338', 'nickname': 'Cauazin'}, {'id': '3301', 'nickname': 'v1nNy'}, {'id': '1686', 'nickname': 'RobbieBk'}, {'id': '10901', 'nickname': 'Virtyy'}], 'startTimeScheduled': '2025-08-21T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'Leviatán Esports', 'id': '1611'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Cloud9', 'id': '79'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFT0NER0FGCwtaCwtFR0VCWkdPWkVFI0dHTUdHTUdHLQ==', 'node': {'id': '2843061', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '826992', 'name': 'VCT Americas - Stage 2 2025 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [{'id': '296', 'nickname': 'Asuna'}, {'id': '2345', 'nickname': 'Boostio'}, {'id': '2361', 'nickname': 'Cryo'}, {'id': '2341', 'nickname': 'eeiu'}, {'id': '2359', 'nickname': 'Zander'}, {'id': '119048', 'nickname': 'Kess'}, {'id': '2347', 'nickname': 'JAWGEMO'}, {'id': '1192', 'nickname': 'leaf'}, {'id': '2351', 'nickname': 'JonahP'}, {'id': '2353', 'nickname': 'trent'}, {'id': '2349', 'nickname': 'valyn'}, {'id': '709', 'nickname': 'BABYBAY'}], 'startTimeScheduled': '2025-08-22T00:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'G2 Esports', 'id': '96'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': '100 Thieves', 'id': '337'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFT0NER0FFCwtaCwtFR0VCWkdPWkVFI0VGTUdHTUdHLQ==', 'node': {'id': '2843062', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '826992', 'name': 'VCT Americas - Stage 2 2025 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [{'id': '1193', 'nickname': 'Xeppaa'}, {'id': '10636', 'nickname': 'OXY'}, {'id': '2348', 'nickname': 'neT'}, {'id': '2890', 'nickname': 'Rossy'}, {'id': '10612', 'nickname': 'v1c'}, {'id': '1195', 'nickname': 'mitch'}, {'id': '272', 'nickname': 'tuyz'}, {'id': '277', 'nickname': 'pANcada'}, {'id': '11338', 'nickname': 'Cauazin'}, {'id': '3301', 'nickname': 'v1nNy'}, {'id': '1686', 'nickname': 'RobbieBk'}, {'id': '10901', 'nickname': 'Virtyy'}, {'id': '727', 'nickname': 'bang'}, {'id': '287', 'nickname': 'zekken'}, {'id': '94', 'nickname': 'Zellsis'}, {'id': '2512', 'nickname': 'johnqt'}, {'id': '11013', 'nickname': 'N4RRATE'}], 'startTimeScheduled': '2025-08-22T21:00:00Z', 'format': {'name': 'best-of-3', 'nameShortened': 'Bo3'}, 'teams': [{'baseInfo': {'name': 'Cloud9', 'id': '79'}, 'scoreAdvantage': 0}, {'baseInfo': {'name': 'Sentinels', 'id': '1079'}, 'scoreAdvantage': 0}]}}, {'cursor': 'JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFT0NER0FECwtaCwtFR0VCWkdPWkVEI0dHTUdHTUdHLQ==', 'node': {'id': '2843063', 'title': {'name': 'Valorant'}, 'type': 'ESPORTS', 'tournament': {'id': '826992', 'name': 'VCT Americas - Stage 2 2025 (Playoffs: Playoffs)', 'nameShortened': 'Playoffs'}, 'players': [{'id': '2347', 'nickname': 'JAWGEMO'}, {'id': '1192', 'nickname': 'leaf'}, {'id': '2351', 'nickname': 'JonahP'}, {'id': '2353', 'nickname': 'trent'}, {'id': '2349', 'nickname': 'valyn'},  ...
# Fetched 12 items. Next page available: False
# Total series collected: 212

# %%
import json
# Save to a file
with open("all_series.json", "w") as f:
    json.dump(all_series, f, indent=4)

# %%
import pandas as pd

def series_to_dataframe(all_series: list) -> pd.DataFrame:
    rows = []

    for edge in all_series:
        s = edge
        # Tournament
        tournament = s.get("tournament", {}) or {}

        # Players
        players = s.get("players", [])
        player_ids = [p["id"] for p in players if "id" in p]

        # Teams
        teams = s.get("teams", [])
        team_ids = [
            t["baseInfo"]["id"]
            for t in teams
            if t.get("baseInfo") and "id" in t["baseInfo"]
        ]

        rows.append({
            "series_id": s.get("id"),

            # "game_name": s.get("title", {}).get("name"),
            "game_id": 6, # valorant ID
            "series_type": s.get("type"),
            "format_name": s.get("format", {}).get("name"),
            "format_short": s.get("format", {}).get("nameShortened"),

            # Tournament linkage
            "tournament_id": tournament.get("id"),
            "tournament_name": tournament.get("name"),

            # Temporal
            "start_date": s.get("startTimeScheduled"),

            # AI signals
            "player_ids": player_ids,
            "team_ids": team_ids,
            "num_players": len(player_ids),
            "num_teams": len(team_ids),
        })

    df = pd.DataFrame(rows)

    df["player_ids"] = df["player_ids"].apply(lambda x: ",".join(x))
    df["team_ids"] = df["team_ids"].apply(lambda x: ",".join(x))

    # Convert datetime for timeline reasoning 
    df["start_date"] = pd.to_datetime(df["start_date"])
    df["start_date"] = df["start_date"].dt.strftime('%Y-%m-%d')


    return df

df_series = series_to_dataframe(all_series)
df_series.head()
# Out:
#   series_id  game_id series_type format_name format_short tournament_id  \
# 0   2629390        6     ESPORTS   best-of-3          Bo3        757073
# 1   2629391        6     ESPORTS   best-of-3          Bo3        757073
# 2   2629392        6     ESPORTS   best-of-3          Bo3        757628
# 3   2629393        6     ESPORTS   best-of-3          Bo3        757628
# 4   2629394        6     ESPORTS   best-of-3          Bo3        757629
#
#                                  tournament_name  start_date player_ids  \
# 0  VCT Americas - Kickoff 2024 (Groups: Group A)  2024-02-16
# 1  VCT Americas - Kickoff 2024 (Groups: Group A)  2024-02-17
# 2  VCT Americas - Kickoff 2024 (Groups: Group B)  2024-02-17
# 3  VCT Americas - Kickoff 2024 (Groups: Group B)  2024-02-18
# 4  VCT Americas - Kickoff 2024 (Groups: Group C)  2024-02-18
#
#     team_ids  num_players  num_teams
# 0      99,97            0          2
# 1      81,79            0          2
# 2  1079,3412            0          2
# 3   337,1611            0          2
# 4   96,48457            0          2

# %%
import pandas as pd

from sqlalchemy import create_engine
# 'sqlite:///filename.db' for local file
engine = create_engine('sqlite:///valorant_esports.db')

df_series.to_sql('series', con=engine, if_exists='replace')
# Out:
# 212

# %% [markdown]
# ## DB player analysis

# %%
import sqlite3
import pandas as pd

# 1. Connect to the database
conn = sqlite3.connect('valorant_esports.db')

# 2. Use a SQL query to fetch data directly into a DataFrame
# query = "SELECT * FROM series"
query = "SELECT * FROM series WHERE player_ids != ''"
df = pd.read_sql_query(query, conn)

# 3. Close the connection
conn.close()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            23 non-null     int64
#  1   series_id        23 non-null     object
#  2   game_id          23 non-null     int64
#  3   series_type      23 non-null     object
#  4   format_name      23 non-null     object
#  5   format_short     23 non-null     object
#  6   tournament_id    23 non-null     object
#  7   tournament_name  23 non-null     object
#  8   start_date       23 non-null     object
#  9   player_ids       23 non-null     object
#  10  team_ids         23 non-null     object
#  11  num_players      23 non-null     int64
#  12  num_teams        23 non-null     int64
# dtypes: int64(4), object(9)
# memory usage: 2.5+ KB

# %%
df['series_id'].value_counts()
# Out:
# series_id
# 2819694    1
# 2819695    1
# 2819696    1
# 2819698    1
# 2819699    1
# 2819700    1
# 2819701    1
# 2819702    1
# 2819703    1
# 2819704    1
# 2819705    1
# 2843060    1
# 2843061    1
# 2843062    1
# 2843063    1
# 2843064    1
# 2843065    1
# 2843067    1
# 2843066    1
# 2843068    1
# 2843069    1
# 2843070    1
# 2843071    1
# Name: count, dtype: int64

# %%
import pandas as pd

df_expanded = df.assign(team_ids=df['team_ids'].str.split(',')).explode('team_ids')

# 2. Group by the Team ID and aggregate 
analysis_df = df_expanded.groupby('team_ids').agg({
    'team_ids': 'count',
    'player_ids': lambda x: list(set(','.join(filter(None, x)).split(',')))
}).rename(columns={'team_ids': 'occurrence_count', 'player_ids': 'associated_players'}).reset_index()

# 2. Add a column that calculates the total count of unique players for each team
analysis_df['player_count'] = analysis_df['associated_players'].apply(len)

# 3. Sort by occurrence to see the top teams first
analysis_df = analysis_df.sort_values(by='occurrence_count', ascending=False).reset_index(drop=True)

# Display the results
analysis_df
# Out:
#    team_ids  occurrence_count  \
# 0        97                 7
# 1        79                 6
# 2        96                 6
# 3      1079                 5
# 4       337                 5
# 5      1611                 4
# 6       281                 3
# 7      3412                 2
# 8     53367                 2
# 9     48457                 2
# 10       81                 2
# 11       99                 2
#
#                                    associated_players  player_count
# 0   [1193, 10612, 206, 10901, 77, 11013, 297, 3078...            40
# 1   [2345, 1193, 10612, 10901, 11013, 297, 1192, 2...            34
# 2   [2345, 1193, 10612, 10901, 11013, 297, 1192, 2...            38
# 3   [1193, 10612, 11013, 10901, 297, 1192, 74432, ...            33
# 4   [2345, 1193, 10612, 10901, 1192, 2359, 307, 33...            29
# 5   [2345, 1193, 10612, 206, 10901, 77, 297, 3078,...            29
# 6   [2345, 11013, 2359, 307, 42759, 2341, 866, 42,...            20
# 7   [2837, 2345, 119048, 629, 2361, 296, 32038, 23...            12
# 8   [10636, 287, 94, 1193, 10612, 1686, 10901, 289...            17
# 9   [2513, 206, 77, 297, 3078, 28813, 74, 2358, 74...            11
# 10  [629, 2837, 2513, 297, 32038, 3320, 2358, 7443...            11
# 11  [2349, 303, 14940, 709, 306, 307, 42759, 32030...            15

# %%
exploded_players = df['player_ids'].dropna().str.split(',').explode()

exploded_players = exploded_players.str.strip()
exploded_players = exploded_players[exploded_players != '']

player_stats_df = exploded_players.value_counts().reset_index()

player_stats_df.columns = ['player_id', 'appearance_count']

player_stats_df = player_stats_df.sort_values(by='appearance_count', ascending=False).reset_index(drop=True)

player_stats_df
# Out:
#    player_id  appearance_count
# 0       2358                 7
# 1      74432                 7
# 2        297                 7
# 3       2513                 7
# 4       2340                 7
# 5      10636                 6
# 6       1193                 6
# 7        272                 6
# 8       1195                 6
# 9      10612                 6
# 10      2890                 6
# 11      2348                 6
# 12       277                 6
# 13      3301                 6
# 14     11338                 6
# 15      1686                 6
# 16     10901                 6
# 17      2349                 6
# 18       709                 6
# 19      2351                 6
# 20      2353                 6
# 21      2347                 6
# 22      1192                 6
# 23    119048                 5
# 24      2361                 5
# 25      2345                 5
# 26       296                 5
# 27     11013                 5
# 28      2512                 5
# 29       287                 5
# 30        94                 5
# 31      2341                 5
# 32      2359                 5
# 33       727                 5
# 34       866                 3
# 35       303                 3
# 36       306                 3
# 37       307                 3
# 38     14940                 3
# 39       629                 2
# 40     10630                 2
# 41      3320                 2
# 42     32038                 2
# 43      2837                 2
# 44        14                 2
# 45        48                 2
# 46     32030                 2
# 47        42                 2
# 48     42759                 2
# 49       208                 2
# 50        74                 2
# 51      3078                 2
# 52        77                 2
# 53       206                 2
# 54     28813                 2

# %%
# 1. Split and explode the team_ids while keeping other IDs attached
# We include series_id and tournament_id here
df_expanded = df.assign(team_ids=df['team_ids'].str.split(',')).explode('team_ids')

# 2. Updated Aggregation: Collect unique Series and Tournament IDs
analysis_df = df_expanded.groupby('team_ids').agg({
    'team_ids': 'count',
    'player_ids': lambda x: list(set(','.join(filter(None, x)).split(','))),
    'series_id': lambda x: list(set(x.dropna())),      # Unique series IDs for this team
    'tournament_id': lambda x: list(set(x.dropna()))  # Unique tournament IDs
}).rename(columns={'team_ids': 'occurrence_count', 'player_ids': 'associated_players'}).reset_index()

# 3. Add the player count column
analysis_df['player_count'] = analysis_df['associated_players'].apply(len)

# 4. Filter for Veteran Teams (using your top_10_player_ids from the previous step)
top_10_player_ids = player_stats_df.head(12)['player_id'].tolist()
has_top_player = lambda players: any(p in top_10_player_ids for p in players)

veteran_teams_df = analysis_df[analysis_df['associated_players'].apply(has_top_player)].copy()

# 5. Add the summary of which top players are in each team
veteran_teams_df['top_players_present'] = veteran_teams_df['associated_players'].apply(
    lambda x: [p for p in x if p in top_10_player_ids]
)

# Sort for the most active veteran teams
veteran_teams_df = veteran_teams_df.sort_values(by='occurrence_count', ascending=False).reset_index(drop=True)
veteran_teams_df['series_count']  = veteran_teams_df['series_id'].count()
veteran_teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team_ids             9 non-null      object
#  1   occurrence_count     9 non-null      int64
#  2   associated_players   9 non-null      object
#  3   series_id            9 non-null      object
#  4   tournament_id        9 non-null      object
#  5   player_count         9 non-null      int64
#  6   top_players_present  9 non-null      object
#  7   series_count         9 non-null      int64
# dtypes: int64(3), object(5)
# memory usage: 708.0+ bytes

# %%
veteran_teams_df['top_players_present'].explode().value_counts()
# Out:
# top_players_present
# 1193      7
# 10612     7
# 10901     7
# 297       7
# 3301      7
# 74432     7
# 2340      7
# 10636     7
# 2358      7
# 2513      7
# 11338     7
# 2890      7
# 277       7
# 2348      7
# 1686      7
# 1195      7
# 272       7
# 1192      6
# 119048    6
# 296       6
# 2359      6
# 2341      6
# 2361      6
# 11013     6
# 2351      6
# 287       6
# 709       6
# 94        6
# 2349      6
# 2353      6
# 727       6
# 2347      6
# 2345      6
# 2512      6
# 303       4
# 866       4
# 306       4
# 307       4
# 14940     4
# 3320      3
# 14        3
# 32038     3
# 2837      3
# 10630     3
# 208       3
# 629       3
# 42759     3
# 48        3
# 42        3
# 32030     3
# Name: count, dtype: int64

# %%
veteran_teams_df['series_id'].explode().value_counts()
# Out:
# series_id
# 2843069    2
# 2843071    2
# 2843070    2
# 2843063    2
# 2819700    2
# 2843067    2
# 2819695    2
# 2819704    2
# 2843062    2
# 2843066    2
# 2819694    2
# 2843060    2
# 2843068    2
# 2819698    2
# 2843061    2
# 2819696    2
# 2819703    2
# 2843065    2
# 2819699    2
# 2819701    2
# 2843064    2
# 2819702    2
# 2819705    2
# Name: count, dtype: int64
